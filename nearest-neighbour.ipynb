# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.neighbors import NearestNeighbors

# %%
train_df = pd.read_csv('data-pipeline/_raw/GLC24_PA_metadata_train.csv')
test_df = pd.read_csv('data-pipeline/_raw/GLC24_PA_metadata_test.csv')

# %%
test_df.shape
# Out:
# (4716, 8)

# %%
test_df.surveyId.value_counts().sort_values(ascending=False)
# Out:
# surveyId
# 642        1
# 32525      1
# 4889       1
# 5884       1
# 6955       1
#           ..
# 3917793    1
# 3918865    1
# 3914890    1
# 3908927    1
# 3919234    1
# Name: count, Length: 4716, dtype: int64

# %%
test_df = test_df.drop(columns=['year', 'geoUncertaintyInM', 'areaInM2', 'region', 'country'])
train_df = train_df.drop(columns=['year', 'geoUncertaintyInM', 'areaInM2', 'region', 'country'])

# %%
train_df.speciesId = train_df.speciesId.astype(int)

# %%
train_df = pd.concat(
    [train_df, pd.get_dummies(train_df['speciesId'], prefix='speciesId')],
    axis=1,
)

# %%
train_df = train_df.drop(columns=['speciesId'])

# %%
train_df = train_df.groupby('surveyId').max().reset_index()

# %%
train_df = train_df.drop(columns=['surveyId'])

# %%
train_df.head()
# Out:
#         lon        lat  speciesId_2  speciesId_3  speciesId_4  speciesId_7  \
# 0  3.099038  43.134956        False        False        False        False
# 1  9.884560  56.912140        False        False        False        False
# 2  8.256020  55.637050        False        False        False        False
# 3 -0.402590  43.505630        False        False        False        False
# 4 -0.517360  45.806430        False        False        False        False
#
#    speciesId_9  speciesId_10  speciesId_12  speciesId_14  ...  \
# 0        False         False         False         False  ...
# 1        False         False         False         False  ...
# 2        False         False         False         False  ...
# 3        False         False         False         False  ...
# 4        False         False         False         False  ...
#
#    speciesId_11239  speciesId_11240  speciesId_11241  speciesId_11242  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    speciesId_11243  speciesId_11245  speciesId_11246  speciesId_11248  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    speciesId_11253  speciesId_11254
# 0            False            False
# 1            False            False
# 2            False            False
# 3            False            False
# 4            False            False
#
# [5 rows x 5018 columns]

# %%
neigh = NearestNeighbors(n_neighbors=1)
neigh.fit(train_df[['lon', 'lat']])
# Out:
# NearestNeighbors(n_neighbors=1)

# %%
test_df['nearest'] = neigh.kneighbors(test_df[['lon', 'lat']], 1, return_distance=False)

# %%
test_df.head()
# Out:
#          lon       lat  surveyId  nearest
# 0  10.033550  57.12081       642    51492
# 1   7.333000  46.22997      1792    26503
# 2   1.843658  42.58006      3256    80814
# 3  11.720090  46.26149      3855      259
# 4   9.361870  55.90245      4889    21119

# %%
test_df.shape
# Out:
# (4716, 4)

# %%
train_df.loc[train_df.index.isin([51492, 26503, 80814,259,21119])]
# Out:
#              lon        lat  speciesId_2  speciesId_3  speciesId_4  \
# 259    11.740398  46.260273        False        False        False
# 21119   9.370440  55.909730        False        False        False
# 26503   7.437620  46.164710        False        False        False
# 51492  10.071700  57.140220        False        False        False
# 80814   1.852500  42.640890        False        False        False
#
#        speciesId_7  speciesId_9  speciesId_10  speciesId_12  speciesId_14  \
# 259          False        False         False         False         False
# 21119        False        False         False         False         False
# 26503        False        False         False         False         False
# 51492        False        False         False         False         False
# 80814        False        False         False         False         False
#
#        ...  speciesId_11239  speciesId_11240  speciesId_11241  \
# 259    ...            False            False             True
# 21119  ...            False            False            False
# 26503  ...            False            False            False
# 51492  ...            False            False            False
# 80814  ...            False            False            False
#
#        speciesId_11242  speciesId_11243  speciesId_11245  speciesId_11246  \
# 259              False            False            False            False
# 21119            False            False            False            False
# 26503            False            False            False            False
# 51492            False            False            False            False
# 80814            False            False            False            False
#
#        speciesId_11248  speciesId_11253  speciesId_11254
# 259              False            False            False
# 21119            False            False            False
# 26503            False            False            False
# 51492            False            False            False
# 80814            False            False            False
#
# [5 rows x 5018 columns]

# %%
combined_test_df = pd.merge(test_df, train_df, left_on='nearest', right_index=True, how='left')

# %%
combined_test_df.head()
# Out:
#        lon_x     lat_x  surveyId  nearest      lon_y      lat_y  speciesId_2  \
# 0  10.033550  57.12081       642    51492  10.071700  57.140220        False
# 1   7.333000  46.22997      1792    26503   7.437620  46.164710        False
# 2   1.843658  42.58006      3256    80814   1.852500  42.640890        False
# 3  11.720090  46.26149      3855      259  11.740398  46.260273        False
# 4   9.361870  55.90245      4889    21119   9.370440  55.909730        False
#
#    speciesId_3  speciesId_4  speciesId_7  ...  speciesId_11239  \
# 0        False        False        False  ...            False
# 1        False        False        False  ...            False
# 2        False        False        False  ...            False
# 3        False        False        False  ...            False
# 4        False        False        False  ...            False
#
#    speciesId_11240  speciesId_11241  speciesId_11242  speciesId_11243  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False             True            False            False
# 4            False            False            False            False
#
#    speciesId_11245  speciesId_11246  speciesId_11248  speciesId_11253  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    speciesId_11254
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
#
# [5 rows x 5022 columns]

# %%
combined_test_df.shape
# Out:
# (4716, 5022)

# %%
combined_test_df.surveyId.value_counts().sort_values(ascending=False)
# Out:
# surveyId
# 642        1
# 32525      1
# 4889       1
# 5884       1
# 6955       1
#           ..
# 3917793    1
# 3918865    1
# 3914890    1
# 3908927    1
# 3919234    1
# Name: count, Length: 4716, dtype: int64

# %%
combined_test_df = combined_test_df.drop(columns=['lon_x','lat_x','nearest','lon_y','lat_y'])

# %%
combined_test_df.sort_values(by='surveyId').head()
# Out:
#    surveyId  speciesId_2  speciesId_3  speciesId_4  speciesId_7  speciesId_9  \
# 0       642        False        False        False        False        False
# 1      1792        False        False        False        False        False
# 2      3256        False        False        False        False        False
# 3      3855        False        False        False        False        False
# 4      4889        False        False        False        False        False
#
#    speciesId_10  speciesId_12  speciesId_14  speciesId_15  ...  \
# 0         False         False         False         False  ...
# 1         False         False         False         False  ...
# 2         False         False         False         False  ...
# 3         False         False         False         False  ...
# 4         False         False         False         False  ...
#
#    speciesId_11239  speciesId_11240  speciesId_11241  speciesId_11242  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False             True            False
# 4            False            False            False            False
#
#    speciesId_11243  speciesId_11245  speciesId_11246  speciesId_11248  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    speciesId_11253  speciesId_11254
# 0            False            False
# 1            False            False
# 2            False            False
# 3            False            False
# 4            False            False
#
# [5 rows x 5017 columns]

# %%
from helper import verify_submission

# %%
species_columns = ["survey"] + list(
    combined_test_df.columns[combined_test_df.columns.str.startswith("speciesId_")]
)

species = [column[10:] for column in species_columns[1:]]

with open("submissions/submission-nearest.csv", "w") as f:
    f.write("surveyId,predictions\n")
    for _, row in tqdm(combined_test_df.sort_values("surveyId").iterrows()):
        f.write(
            str(row[0])
            + ","
            + " ".join([species[i - 1] for i in range(1, len(row)) if row[i] == 1])
            + "\n"
        )
# Out:
# 0it [00:00, ?it/s]/tmp/ipykernel_65077/973873321.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   str(row[0])
# /tmp/ipykernel_65077/973873321.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   + " ".join([species[i - 1] for i in range(1, len(row)) if row[i] == 1])
# 4716it [01:13, 64.59it/s]

# %%
verify_submission("submission-nearest.csv")
# Out:
# True

# %%
count_species = 0
with open("submission-nearest.csv", "r") as f:
    for line in f:
        count_species += len(line.split(",")[1].split())
mean_species = count_species / 4716
print(f"Mean number of species per survey: {mean_species:.2f}")
# Out:
# Mean number of species per survey: 16.87
